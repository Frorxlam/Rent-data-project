# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/_data.csv', index_col=0)
df
# Out:
#        ID  объявления Количество комнат       Тип  \
# 0           271271157                 4  Квартира
# 1           271634126                 4  Квартира
# 2           271173086   4, Оба варианта  Квартира
# 3           272197456   4, Оба варианта  Квартира
# 4           273614615                 2  Квартира
# ...               ...               ...       ...
# 23363       215565511               NaN  Квартира
# 23364       274654844                 1  Квартира
# 23365       268679909   2, Оба варианта  Квартира
# 23366       274807525                 2  Квартира
# 23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# ...

# %%
df['City'] = df['Адрес'].str.split(',').str[0]
# Удалить все строки, где значение в столбце 'City' не равно 'Москва'
df.drop(df[df['City'] != 'Москва'].index, inplace=True)
df
# Out:
#        ID  объявления Количество комнат       Тип  \
# 0           271271157                 4  Квартира
# 1           271634126                 4  Квартира
# 2           271173086   4, Оба варианта  Квартира
# 3           272197456   4, Оба варианта  Квартира
# 4           273614615                 2  Квартира
# ...               ...               ...       ...
# 23363       215565511               NaN  Квартира
# 23364       274654844                 1  Квартира
# 23365       268679909   2, Оба варианта  Квартира
# 23366       274807525                 2  Квартира
# 23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# ...

# %%
df = df.rename(columns={'ID объявления': 'id', 'Количество комнат': 'rms_qty', 'Тип': 'type', 'Метро': 'metro', 'Площадь, м2': 'square', 'Дом': 'floor', 'Парковка': 'parking', 'Санузел': 'bath_type', 'Можно с детьми/животными': 'kids_pets_allowed', 'Дополнительно': 'misc', 'Лифт': 'lift', 'Мусоропровод': 'trash_pype'})
df
# Out:
#        ID  объявления          rms_qty      type  \
# 0           271271157                4  Квартира
# 1           271634126                4  Квартира
# 2           271173086  4, Оба варианта  Квартира
# 3           272197456  4, Оба варианта  Квартира
# 4           273614615                2  Квартира
# ...               ...              ...       ...
# 23363       215565511              NaN  Квартира
# 23364       274654844                1  Квартира
# 23365       268679909  2, Оба варианта  Квартира
# 23366       274807525                2  Квартира
# 23367       274672243  2, Оба варианта  Квартира
#
#                               metro  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# 23365    м. Солнцево (6 мин пешком)
# ...

# %%
df['metro'] = df['metro'].str.replace(r'м\. (.+?) \(.+\)', r'\1', regex=True)
df
# Out:
#        ID  объявления          rms_qty      type       metro  \
# 0           271271157                4  Квартира  Смоленская
# 1           271634126                4  Квартира  Смоленская
# 2           271173086  4, Оба варианта  Квартира  Смоленская
# 3           272197456  4, Оба варианта  Квартира  Смоленская
# 4           273614615                2  Квартира   Арбатская
# ...               ...              ...       ...         ...
# 23363       215565511              NaN  Квартира    Говорово
# 23364       274654844                1  Квартира    Солнцево
# 23365       268679909  2, Оба варианта  Квартира    Солнцево
# 23366       274807525                2  Квартира    Солнцево
# 23367       274672243  2, Оба варианта  Квартира    Говорово
#
#                                                    Адрес           square  \
# 0                          Москва, улица Новый Арбат, 27       200.0/20.0
# 1                          Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# ...

# %%
keys = ['Красные Ворота', 'Чистые пруды', 'Лубянка', 'Охотный ряд', 'Театральная', 'Новокузнецкая', 'Тверская', 'Арбатская', 'Площадь Революции', 'Курская', 'Александровский сад', 'Парк культуры', 'Октябрьская', 'Добрынинская', 'Павелецкая', 'Таганская', 'Краснопресненская', 'Киевская']
value = 4
gard_ring = dict.fromkeys(keys, value)

keys = ['Фрунзенская', 'Спортивная', 'Воробьёвы горы', 'Лужники', 'Киевская', 'Выставочная', 'Деловой центр', 'Международная', 'Студенческая', 'Кутузовская', 'Фили', 'Беговая', 'Улица 1905 года', 'Баррикадная', 'Краснопресненская', 
        'Белорусская', 'Маяковская', 'Новослободская', 'Менделеевская', 'Савёловская', 'Достоевская', 'Марьина Роща', 'Проспект Мира', 'Сухаревская', 'Цветной бульвар', 'Трубная', 'Тургеневская', 'Сретенский бульвар', 'Чкаловская', 
        'Марксистская', 'Пролетарская', 'Крестьянская застава', 'Серпуховская', 'Павелецкая', 'Добрынинская', 'Тульская', 'Шаболовская', 'Ленинский проспект', 'Шелепиха', 'Хорошёвская', 'Аминьевская', 'Народное Ополчение', 'Карамышевская',
        'Зорге', 'Рижская', 'Сокольники', 'Электрозаводская', 'Лефортово', 'Авиамоторная', 'Текстильщики', 'Печатники', 'Каширская', 'Новаторская', 'Воронцовская', 'Лужники', 'Площадь Гагарина', 'Шелепиха', 'Хорошёво', 'Зорге', 'Панфиловская', 
        'Стрешнево', 'Балтийская', 'Коптево', 'Лихоборы', 'Окружная', 'Владыкино', 'Ростокино', 'Белокаменная', 'Андроновка', 'Новохохловская', 'Угрешская', 'Дубровка', 'ЗИЛ', 'Верхние Котлы', 'Крымская', 'Тимирязевская', 'Окружная', 'Владыкино', 
        'Ботанический сад', 'Савёловская', 'Рижская', 'Курская', 'Павелецкая']
value = 3
thrd_ring = dict.fromkeys(keys, value)

keys = []
value = 2
thrd_ring = dict.fromkeys(keys, value)
# Out:
# {'Красные Ворота': 4,
#  'Чистые пруды': 4,
#  'Лубянка': 4,
#  'Охотный ряд': 4,
#  'Театральная': 4,
#  'Новокузнецкая': 4,
#  'Тверская': 4,
#  'Арбатская': 4,
#  'Площадь Революции': 4,
#  'Курская': 4,
#  'Александровский сад': 4,
#  'Парк культуры': 4,
#  'Октябрьская': 4,
#  'Добрынинская': 4,
#  'Павелецкая': 4,
#  'Таганская': 4,
#  'Краснопресненская': 4,
#  'Киевская': 4}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23368 entries, 0 to 23367
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID  объявления            23368 non-null  int64
#  1   Количество комнат         22327 non-null  object
#  2   Тип                       23368 non-null  object
#  3   Метро                     22053 non-null  object
#  4   Адрес                     23368 non-null  object
#  5   Площадь, м2               23368 non-null  object
#  6   Дом                       23368 non-null  object
#  7   Парковка                  9951 non-null   object
#  8   Цена                      23368 non-null  object
#  9   Телефоны                  23368 non-null  object
#  10  Описание                  23368 non-null  object
#  11  Ремонт                    20613 non-null  object
#  12  Площадь комнат, м2        14458 non-null  object
# ...

# %%
df.shape
# Out:
# (23368, 24)

# %%
df.nunique()
# Out:
# ID  объявления              23368
# Количество комнат              24
# Тип                             1
# Метро                        5866
# Адрес                       12850
# Площадь, м2                 11255
# Дом                          2565
# Парковка                        5
# Цена                         3922
# Телефоны                    13172
# Описание                    23078
# Ремонт                          4
# Площадь комнат, м2           3990
# Балкон                         18
# Окна                            3
# Санузел                        20
# Можно с детьми/животными        3
# Дополнительно                 528
# Название ЖК                  1798
# Серия дома                    393
# Высота потолков, м             95
# Лифт                           34
# Мусоропровод                    2
# Ссылка на объявление        23368
# dtype: int64

# %%
df['Square'] = df['Площадь, м2'].str.split('/').str[0]

df['Square'] = pd.to_numeric(df['Square'])

df['Rooms'] = df['Количество комнат'].str.split(',').str[0]

df['Rooms'] = pd.to_numeric(df['Rooms'])

# %%
# Избавляемся от выбросов

def remove_outliers(group, column):
    Q1 = group[column].quantile(0.25)
    Q3 = group[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return group[(group[column] >= lower_bound) & (group[column] <= upper_bound)]

df_cleaned = df.groupby('Rooms').apply(remove_outliers, 'Square').reset_index(drop=True)


mean = df_cleaned.groupby('Rooms')['Square'].mean()
mean
# Out:
# /tmp/ipykernel_14229/256090886.py:11: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_cleaned = df.groupby('Rooms').apply(remove_outliers, 'Square').reset_index(drop=True)
# Rooms
# 1.0     37.002295
# 2.0     52.892711
# 3.0     86.202960
# 4.0    146.487108
# 5.0    204.533048
# 6.0    306.899219
# Name: Square, dtype: float64

# %%
def fill_missing_rooms(row):
    if pd.isna(row['Rooms']):
        
        closest_room_count = mean.sub(row['Square']).abs().idxmin()
        return closest_room_count
    else:
        return row['Rooms']


df['Rooms'] = df.apply(fill_missing_rooms, axis=1)

# %%
df['Clear_price'] = df['Цена'].str.split().str[0]
df['Clear_price'] = pd.to_numeric(df['Clear_price'])
df

df_price_clean = df.groupby('Ремонт').apply(remove_outliers, 'Clear_price').reset_index(drop=True)
df_price_clean

price_mean = df_price_clean.groupby('Ремонт')['Clear_price'].mean()
price_mean

def fill_missing_renovation(row):
    if pd.isna(row['Ремонт']):
        
        closest_renov_count = price_mean.sub(row['Clear_price']).abs().idxmin()
        return closest_renov_count
    else:
        return row['Ремонт']


df['Ремонт'] = df.apply(fill_missing_renovation, axis=1)
# Out:
# /tmp/ipykernel_14229/595739740.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_price_clean = df.groupby('Ремонт').apply(remove_outliers, 'Clear_price').reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23368 entries, 0 to 23367
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID  объявления            23368 non-null  int64
#  1   Количество комнат         22327 non-null  object
#  2   Тип                       23368 non-null  object
#  3   Метро                     22053 non-null  object
#  4   Адрес                     23368 non-null  object
#  5   Площадь, м2               23368 non-null  object
#  6   Дом                       23368 non-null  object
#  7   Парковка                  9951 non-null   object
#  8   Цена                      23368 non-null  object
#  9   Телефоны                  23368 non-null  object
#  10  Описание                  23368 non-null  object
#  11  Ремонт                    23368 non-null  object
#  12  Площадь комнат, м2        14458 non-null  object
# ...
