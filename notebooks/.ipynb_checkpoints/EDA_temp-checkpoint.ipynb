# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[118], line 5
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 5 import mpld3
#
# ModuleNotFoundError: No module named 'mpld3'

# %%
df = pd.read_csv('./data/_data.csv', index_col=0)
df.head(5)
# Out:
#    ID  объявления Количество комнат       Тип                         Метро  \
# 0       271271157                 4  Квартира  м. Смоленская (9 мин пешком)
# 1       271634126                 4  Квартира  м. Смоленская (8 мин пешком)
# 2       271173086   4, Оба варианта  Квартира  м. Смоленская (7 мин пешком)
# 3       272197456   4, Оба варианта  Квартира  м. Смоленская (3 мин пешком)
# 4       273614615                 2  Квартира   м. Арбатская (7 мин пешком)
#
#                               Адрес      Площадь, м2  \
# 0     Москва, улица Новый Арбат, 27       200.0/20.0
# 1     Москва, улица Новый Арбат, 27  198.0/95.0/18.0
# 2     Москва, улица Новый Арбат, 27  200.0/116.0/4.0
# 3  Москва, переулок Плотников, 21С1  170.0/95.0/17.0
# 4     Москва, улица Новый Арбат, 15    58.0/38.0/5.0
#
#                          Дом   Парковка  \
# 0           5/16, Монолитный  подземная
# 1  5/16, Монолитно-кирпичный  подземная
# 2                       5/16  подземная
# ...

# %%
a = df.groupby('Тип').size()
b = df.groupby('Количество комнат').size()
c = df.groupby('Название ЖК').size().sort_values(ascending=False).reset_index()

# %%
df['Первая_площадь'] = df['Площадь, м2'].str.split('/').str[0]

df['Первая_площадь'] = pd.to_numeric(df['Первая_площадь'])

df['Количество_комнат_без_типов'] = df['Количество комнат'].str.split(',').str[0]

df['Количество_комнат_без_типов'] = pd.to_numeric(df['Количество_комнат_без_типов'])



df
# Out:
#        ID  объявления Количество комнат       Тип  \
# 0           271271157                 4  Квартира
# 1           271634126                 4  Квартира
# 2           271173086   4, Оба варианта  Квартира
# 3           272197456   4, Оба варианта  Квартира
# 4           273614615                 2  Квартира
# ...               ...               ...       ...
# 23363       215565511               NaN  Квартира
# 23364       274654844                 1  Квартира
# 23365       268679909   2, Оба варианта  Квартира
# 23366       274807525                 2  Квартира
# 23367       274672243   2, Оба варианта  Квартира
#
#                               Метро  \
# 0      м. Смоленская (9 мин пешком)
# 1      м. Смоленская (8 мин пешком)
# 2      м. Смоленская (7 мин пешком)
# 3      м. Смоленская (3 мин пешком)
# 4       м. Арбатская (7 мин пешком)
# ...                             ...
# 23363    м. Говорово (8 мин пешком)
# 23364    м. Солнцево (7 мин пешком)
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Первая_площадь', y='Количество_комнат_без_типов', alpha=0.6)
plt.title('Зависимость площади квартир от количества комнат')
plt.xlabel('Площадь квартиры (кв.м)')
plt.ylabel('Количество комнат')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Первая_площадь'])
plt.title('Boxplot площади квартир')
plt.xlabel('Площадь квартиры (кв.м)')
plt.grid(True)

# %%
plt.figure(figsize=(10, 6))
room_counts = df['Количество_комнат_без_типов'].value_counts().sort_index()
sns.barplot(x=room_counts.index, y=room_counts.values)
plt.xlabel('Количество комнат')
plt.ylabel('Количество квартир')
plt.title('Количество квартир по числу комнат')
plt.xticks(rotation=90);

# %%
median_price = df.groupby('Количество_комнат_без_типов')['Цена за месяц'].median().reset_index()
sns.barplot(x='Количество_комнат_без_типов', y='Цена за месяц', data=median_price);

# %%
interior = df.groupby('Ремонт')['Ремонт'].count()
bath = df.groupby('Санузел')['Санузел'].count()
kids_pets = df.groupby('Можно с детьми/животными')['Можно с детьми/животными'].count()
elevator = df.groupby('Лифт')['Лифт'].count()
trash = df.groupby('Мусоропровод')['Мусоропровод'].count()
floor_split = df['Дом'].str.split('/').str[0]
floor = df.groupby(floor)['Дом'].count()

# %%
sns.barplot(x=interior.index, y=interior.values)
plt.xlabel('Вид ремонта')
plt.ylabel('Количество квартир')
plt.title('В подавляющем количестве квартир сделан дизайнерский или евро ремонт')
# Out:
# Text(0.5, 1.0, 'В подавляющем количестве квартир сделан дизайнерский или евро ремонт')

# %%
sns.barplot(x=bath.index, y=bath.values)
plt.xlabel('Тип и количество санузлов')
plt.ylabel('Количество квартир')
plt.title('С большим отрывом доминируют варианты с совмещенным санузлом')
plt.xticks(rotation=90);

# %%
sns.barplot(x=kids_pets.index, y=kids_pets.values)
plt.xlabel('Тип и количество санузлов')
plt.ylabel('Возможности заселения')
plt.title('Почти в половине объявлений разрещено проживать с детьми')
plt.xticks(rotation=-20);

# %%
sns.barplot(x=elevator.index, y=elevator.values)
plt.xlabel('Тип и количество лифтов')
plt.ylabel('Количество предложений')
plt.title('Большое количество домов только с пассажирским лифтом')
plt.xticks(rotation=90);

# %%
sns.barplot(x=trash.index, y=trash.values)
plt.xlabel('Наличие мусоропровода')
plt.ylabel('Количество квартир')
plt.title('Вариантов без мусоропровода практически не представлено');

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=floor.index, y=floor.values)
plt.xlabel('Этажи')
plt.ylabel('Количество квартир')
plt.title('В основном квартиры предлагаются на нижних этажах')
plt.xticks(rotation=90);

# %%
savef
# Out:
#   Cell In[119], line 1
#     jupyter nbconvert --to html EDA.ipynb
#             ^
# SyntaxError: invalid syntax
